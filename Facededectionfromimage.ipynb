# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("1.jpg")

# %%
img.shape
# Out:
# (800, 1200, 3)

# %%
plt.imshow(img);

# %%
gray_scale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray_scale
# Out:
# array([[219, 220, 218, ..., 226, 228, 228],
#        [219, 219, 219, ..., 228, 229, 227],
#        [219, 219, 221, ..., 227, 228, 227],
#        ...,
#        [143, 146, 149, ..., 131, 132, 131],
#        [148, 148, 145, ..., 135, 135, 135],
#        [146, 146, 144, ..., 137, 142, 141]], dtype=uint8)

# %%
print(gray_scale.shape)
# Out:
# (800, 1200)

# %%
print(gray_scale.size)
# Out:
# 960000

# %%
print(img.shape)
# Out:
# (800, 1200, 3)

# %%
print(img.size)
# Out:
# 2880000

# %%
plt.imshow(gray_scale);

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
faces = face_cascade.detectMultiScale(gray_scale, 1.2, 5)
faces
# Out:
# array([[ 778,  441,   41,   41],
#        [ 666,  610,   31,   31],
#        [ 583,  446,   33,   33],
#        [ 730,  449,   29,   29],
#        [  88,  450,   35,   35],
#        [1043,  443,   49,   49],
#        [ 677,  452,   38,   38],
#        [ 695,  647,   29,   29],
#        [ 547,  657,   29,   29],
#        [ 789,  654,   37,   37],
#        [ 643,  660,   31,   31],
#        [ 738,  639,   34,   34],
#        [ 399,  464,   34,   34],
#        [ 486,  467,   31,   31],
#        [ 198,  467,   43,   43],
#        [ 866,  472,   33,   33],
#        [ 241,  520,   35,   35],
#        [ 894,  522,   30,   30],
#        [ 724,  528,   31,   31],
#        [ 942,  526,   31,   31],
#        [ 611,  532,   31,   31],
#        [ 841,  529,   33,   33],
#        [ 462,  550,   30,   30],
#        [1001,  547,   36,   36],
#        [ 127,  534,   37,   37],
#        [ 404,  532,   33,   33],
#        [ 541,  544,   30,   30],
#        [ 298,  554,   41,   41],
#        [ 966,  533,  118,  118]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,0,255), 4)
    
cv2.imshow("face detection", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def detectfromImage(image):
    face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
    img = cv2.imread(image)
    grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray_scale, 1.2, 1)
    
    for(x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 4)
    cv2.imshow("baslik", img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
detectfromImage("1.jpg")
